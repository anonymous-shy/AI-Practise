# %%
import tushare as ts
import pandas as pd
import numpy as np

# %%
ts.get_hist_data('600519') # 一次性获取日K数据
# Out:
#                open     high    close      low    volume  price_change  \
# date
# 2019-11-18  1225.12  1229.45  1227.00  1218.00  17461.83          2.10
# 2019-11-15  1230.00  1232.91  1224.90  1221.50  16340.72         -5.10
# 2019-11-14  1227.00  1240.00  1230.00  1222.00  23521.12          6.00
# 2019-11-13  1207.00  1227.80  1224.00  1200.00  31977.04         22.40
# 2019-11-12  1204.00  1209.60  1201.60  1198.21  19150.55          2.60
# ...             ...      ...      ...      ...       ...           ...
# 2017-05-26   450.82   455.60   451.92   448.00  27386.64          1.32
# 2017-05-25   448.71   452.96   450.60   447.50  28898.42          0.28
# 2017-05-24   452.90   456.48   450.32   446.00  40226.18         -3.88
# 2017-05-23   442.25   454.47   454.20   442.25  48454.39         12.42
# 2017-05-22   439.04   446.01   441.78   436.20  35321.49          0.96
#
#             p_change       ma5      ma10      ma20     v_ma5    v_ma10  \
# date
# ...
